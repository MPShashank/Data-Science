# %%
import pandas as pd

# %%
label = ['a','b','c']

# %%
data=[10,20,30]

# %%
pd.Series(data=data,index=label)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(dict)
# Out:
# 0    <class 'dict'>
# dtype: object

# %%
dict={'a':10,'b':20,'c':40}

# %%
import numpy as np

# %%
pd.Series(label)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
np.random.seed(100)

# %%
from numpy.random import randn

# %%
randn(5,4)
# Out:
# array([[-1.74976547,  0.3426804 ,  1.1530358 , -0.25243604],
#        [ 0.98132079,  0.51421884,  0.22117967, -1.07004333],
#        [-0.18949583,  0.25500144, -0.45802699,  0.43516349],
#        [-0.58359505,  0.81684707,  0.67272081, -0.10441114],
#        [-0.53128038,  1.02973269, -0.43813562, -1.11831825]])

# %%
data = pd.DataFrame(randn(5,4), ['A', 'B', 'C', 'D', 'E'], ['P', 'Q', 'R', 'S'])

# %%
data
# Out:
#           P         Q         R         S
# A  1.618982  1.541605 -0.251879 -0.842436
# B  0.184519  0.937082  0.731000  1.361556
# C -0.326238  0.055676  0.222400 -1.443217
# D -0.756352  0.816454  0.750445 -0.455947
# E  1.189622 -1.690617 -1.356399 -1.232435

# %%
data['P']
# Out:
# A    1.618982
# B    0.184519
# C   -0.326238
# D   -0.756352
# E    1.189622
# Name: P, dtype: float64

# %%
data[['P','Q']]
# Out:
#           P         Q
# A  1.618982  1.541605
# B  0.184519  0.937082
# C -0.326238  0.055676
# D -0.756352  0.816454
# E  1.189622 -1.690617

# %%
data['new']=[1,2,3,4,6]

# %%
data
# Out:
#           P         Q         R         S  new
# A  1.618982  1.541605 -0.251879 -0.842436    1
# B  0.184519  0.937082  0.731000  1.361556    2
# C -0.326238  0.055676  0.222400 -1.443217    3
# D -0.756352  0.816454  0.750445 -0.455947    4
# E  1.189622 -1.690617 -1.356399 -1.232435    6

# %%
data['P+R']=data['P']+data['R']
data
# Out:
#           P         Q         R         S  new       P+R
# A  1.618982  1.541605 -0.251879 -0.842436    1  1.367103
# B  0.184519  0.937082  0.731000  1.361556    2  0.915519
# C -0.326238  0.055676  0.222400 -1.443217    3 -0.103838
# D -0.756352  0.816454  0.750445 -0.455947    4 -0.005908
# E  1.189622 -1.690617 -1.356399 -1.232435    6 -0.166777

# %%
data.drop('new',axis=1,inplace=True)

# %%
data
# Out:
#           P         Q         R         S       P+R
# A  1.618982  1.541605 -0.251879 -0.842436  1.367103
# B  0.184519  0.937082  0.731000  1.361556  0.915519
# C -0.326238  0.055676  0.222400 -1.443217 -0.103838
# D -0.756352  0.816454  0.750445 -0.455947 -0.005908
# E  1.189622 -1.690617 -1.356399 -1.232435 -0.166777

# %%
data.shape
# Out:
# (5, 5)

# %%
data.drop('A')
# Out:
#           P         Q         R         S       P+R
# B  0.184519  0.937082  0.731000  1.361556  0.915519
# C -0.326238  0.055676  0.222400 -1.443217 -0.103838
# D -0.756352  0.816454  0.750445 -0.455947 -0.005908
# E  1.189622 -1.690617 -1.356399 -1.232435 -0.166777

# %%
data.drop('B')
# Out:
#           P         Q         R         S       P+R
# A  1.618982  1.541605 -0.251879 -0.842436  1.367103
# C -0.326238  0.055676  0.222400 -1.443217 -0.103838
# D -0.756352  0.816454  0.750445 -0.455947 -0.005908
# E  1.189622 -1.690617 -1.356399 -1.232435 -0.166777

# %%
data.drop('E')
# Out:
#           P         Q         R         S       P+R
# A  1.618982  1.541605 -0.251879 -0.842436  1.367103
# B  0.184519  0.937082  0.731000  1.361556  0.915519
# C -0.326238  0.055676  0.222400 -1.443217 -0.103838
# D -0.756352  0.816454  0.750445 -0.455947 -0.005908

# %%
data
# Out:
#           P         Q         R         S       P+R
# A  1.618982  1.541605 -0.251879 -0.842436  1.367103
# B  0.184519  0.937082  0.731000  1.361556  0.915519
# C -0.326238  0.055676  0.222400 -1.443217 -0.103838
# D -0.756352  0.816454  0.750445 -0.455947 -0.005908
# E  1.189622 -1.690617 -1.356399 -1.232435 -0.166777

# %%
data.loc['A']
# Out:
# P      1.618982
# Q      1.541605
# R     -0.251879
# S     -0.842436
# P+R    1.367103
# Name: A, dtype: float64

# %%
data.loc[['A','C']]
# Out:
#           P         Q         R         S       P+R
# A  1.618982  1.541605 -0.251879 -0.842436  1.367103
# C -0.326238  0.055676  0.222400 -1.443217 -0.103838

# %%
data.iloc[0]
# Out:
# P      1.618982
# Q      1.541605
# R     -0.251879
# S     -0.842436
# P+R    1.367103
# Name: A, dtype: float64

# %%
data.iloc[1:3]
# Out:
#           P         Q       R         S       P+R
# B  0.184519  0.937082  0.7310  1.361556  0.915519
# C -0.326238  0.055676  0.2224 -1.443217 -0.103838

# %%
data.iloc[:]
# Out:
#           P         Q         R         S       P+R
# A  1.618982  1.541605 -0.251879 -0.842436  1.367103
# B  0.184519  0.937082  0.731000  1.361556  0.915519
# C -0.326238  0.055676  0.222400 -1.443217 -0.103838
# D -0.756352  0.816454  0.750445 -0.455947 -0.005908
# E  1.189622 -1.690617 -1.356399 -1.232435 -0.166777

# %%
data.loc['B','S']
# Out:
# 1.361556125145331

# %%
data.loc[['C','D'],['R','S']]
# Out:
#           R         S
# C  0.222400 -1.443217
# D  0.750445 -0.455947

# %%
data.iloc[2:4,2:4]
# Out:
#           R         S
# C  0.222400 -1.443217
# D  0.750445 -0.455947

# %%
data
# Out:
#           P         Q         R         S       P+R
# A  1.618982  1.541605 -0.251879 -0.842436  1.367103
# B  0.184519  0.937082  0.731000  1.361556  0.915519
# C -0.326238  0.055676  0.222400 -1.443217 -0.103838
# D -0.756352  0.816454  0.750445 -0.455947 -0.005908
# E  1.189622 -1.690617 -1.356399 -1.232435 -0.166777

# %%
data.drop('P',axis=1,inplace=True)

# %%
data
# Out:
#           Q         R         S       P+R
# A  1.541605 -0.251879 -0.842436  1.367103
# B  0.937082  0.731000  1.361556  0.915519
# C  0.055676  0.222400 -1.443217 -0.103838
# D  0.816454  0.750445 -0.455947 -0.005908
# E -1.690617 -1.356399 -1.232435 -0.166777

# %%
data.drop('A',axis=0)
# Out:
#           Q         R         S       P+R
# B  0.937082  0.731000  1.361556  0.915519
# C  0.055676  0.222400 -1.443217 -0.103838
# D  0.816454  0.750445 -0.455947 -0.005908
# E -1.690617 -1.356399 -1.232435 -0.166777

# %%
data2 = pd.DataFrame(np.random.randn(6,6), ['A', 'B', 'C', 'D', 'E', 'F'], ['U', 'V', 'W', 'X' , 'Y' , 'Z'])

# %%
data2
# Out:
#           U         V         W         X         Y         Z
# A -0.544439 -0.668172  0.007315 -0.612939  1.299748 -1.733096
# B -0.983310  0.357508 -1.613579  1.470714 -1.188018 -0.549746
# C -0.940046 -0.827932  0.108863  0.507810 -0.862227  1.249470
# D -0.079611 -0.889731 -0.881798  0.018639  0.237845  0.013549
# E -1.635529 -1.044210  0.613039  0.736205  1.026921 -1.432191
# F -1.841188  0.366093 -0.331777 -0.689218  2.034608 -0.550714

# %%
bool1=data2>0

# %%
data2[bool1]
# Out:
#     U         V         W         X         Y         Z
# A NaN       NaN  0.007315       NaN  1.299748       NaN
# B NaN  0.357508       NaN  1.470714       NaN       NaN
# C NaN       NaN  0.108863  0.507810       NaN  1.249470
# D NaN       NaN       NaN  0.018639  0.237845  0.013549
# E NaN       NaN  0.613039  0.736205  1.026921       NaN
# F NaN  0.366093       NaN       NaN  2.034608       NaN

# %%
data2>0
# Out:
#        U      V      W      X      Y      Z
# A  False  False   True  False   True  False
# B  False   True  False   True  False  False
# C  False  False   True   True  False   True
# D  False  False  False   True   True   True
# E  False  False   True   True   True  False
# F  False   True  False  False   True  False

# %%
data2['W']>0
# Out:
# A     True
# B    False
# C     True
# D    False
# E     True
# F    False
# Name: W, dtype: bool

# %%
data2[data2['W']>0]
# Out:
#           U         V         W         X         Y         Z
# A -0.544439 -0.668172  0.007315 -0.612939  1.299748 -1.733096
# C -0.940046 -0.827932  0.108863  0.507810 -0.862227  1.249470
# E -1.635529 -1.044210  0.613039  0.736205  1.026921 -1.432191

# %%
data2[(data2['W']>0) & (data2['U']<0)]
# Out:
#           U         V         W         X         Y         Z
# A -0.544439 -0.668172  0.007315 -0.612939  1.299748 -1.733096
# C -0.940046 -0.827932  0.108863  0.507810 -0.862227  1.249470
# E -1.635529 -1.044210  0.613039  0.736205  1.026921 -1.432191

# %%
sales_data = {'Company':['Google', 'Amazon', 'Microsoft', 'Google', 'Amazon', 'Microsoft'],
              'Employee': ['A', 'B', 'C', 'D','E', 'F' ],
              'Sales': [100, 200, 300, 200, 230, 220]}

# %%
sales = pd.DataFrame(sales_data)

# %%
sales
# Out:
#      Company Employee  Sales
# 0     Google        A    100
# 1     Amazon        B    200
# 2  Microsoft        C    300
# 3     Google        D    200
# 4     Amazon        E    230
# 5  Microsoft        F    220

# %%
sales=sales.groupby('Company')

# %%
sales.sum()
# Out:
#            Sales
# Company
# Amazon       430
# Google       300
# Microsoft    520

# %%
sales.mean()
# Out:
#            Sales
# Company
# Amazon       215
# Google       150
# Microsoft    260

# %%
sales.max()
# Out:
#           Employee  Sales
# Company
# Amazon           E    230
# Google           D    200
# Microsoft        F    300

# %%
sales.min()
# Out:
#           Employee  Sales
# Company
# Amazon           B    200
# Google           A    100
# Microsoft        C    220

# %%
sal=pd.read_csv('C:/Drivers/Salaries.csv')

# %%
sal.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %%
sal.head(20)
# Out:
#     Id        EmployeeName                                          JobTitle  \
# 0    1      NATHANIEL FORD    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1    2        GARY JIMENEZ                   CAPTAIN III (POLICE DEPARTMENT)
# 2    3      ALBERT PARDINI                   CAPTAIN III (POLICE DEPARTMENT)
# 3    4   CHRISTOPHER CHONG              WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    5     PATRICK GARDNER      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5    6      DAVID SULLIVAN                         ASSISTANT DEPUTY CHIEF II
# 6    7           ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 7    8       DAVID KUSHNER                    DEPUTY DIRECTOR OF INVESTMENTS
# 8    9      MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 9   10  JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 10  11       ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# ...

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
sal.tail()
# Out:
#             Id   EmployeeName                    JobTitle  BasePay  \
# 148649  148650  Roy I Tillery                   Custodian      0.0
# 148650  148651   Not provided                Not provided      NaN
# 148651  148652   Not provided                Not provided      NaN
# 148652  148653   Not provided                Not provided      NaN
# 148653  148654      Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148649          0.0      0.00       0.0      0.00              0.00  2014
# 148650          NaN       NaN       NaN      0.00              0.00  2014
# 148651          NaN       NaN       NaN      0.00              0.00  2014
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency  Status
# 148649    NaN  San Francisco     NaN
# 148650    NaN  San Francisco     NaN
# ...

# %%
sal.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448841    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
sal.iloc[10:20]
# Out:
#     Id       EmployeeName                                          JobTitle  \
# 10  11      ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 11  12   PATRICIA JACKSON                   CAPTAIN III (POLICE DEPARTMENT)
# 12  13  EDWARD HARRINGTON                       EXECUTIVE CONTRACT EMPLOYEE
# 13  14        JOHN MARTIN                                 DEPARTMENT HEAD V
# 14  15     DAVID FRANKLIN                BATTALION CHIEF, (FIRE DEPARTMENT)
# 15  16    RICHARD CORRIEA                COMMANDER III, (POLICE DEPARTMENT)
# 16  17           AMY HART                                 DEPARTMENT HEAD V
# 17  18     SEBASTIAN WONG             CAPTAIN, EMERGENCYCY MEDICAL SERVICES
# 18  19         MARTY ROSS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 19  20      ELLEN MOFFATT                        ASSISTANT MEDICAL EXAMINER
#
#       BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# ...

# %%
sal['BasePay'].sum()
# Out:
# 9819151073.590002
