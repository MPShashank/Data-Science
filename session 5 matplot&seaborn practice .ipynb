# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd

# %%
x = np.linspace(0,5,13)

# %%
y = x**2

# %%
x
# Out:
# array([0.        , 0.41666667, 0.83333333, 1.25      , 1.66666667,
#        2.08333333, 2.5       , 2.91666667, 3.33333333, 3.75      ,
#        4.16666667, 4.58333333, 5.        ])

# %%
y
# Out:
# array([ 0.        ,  0.17361111,  0.69444444,  1.5625    ,  2.77777778,
#         4.34027778,  6.25      ,  8.50694444, 11.11111111, 14.0625    ,
#        17.36111111, 21.00694444, 25.        ])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,'r')

# %%
plt.plot(x,y,'y')

# %%
plt.plot(x,y,'o')

# %%
plt.plot(x,y,'orange')

# %%
'hello'
# Out:
# 'hello'

# %%
print('hello')
# Out:
# hello

# %%
plt.plot(x,y,'red')

# %%
plt.plot(x,y,'red')
plt.show()

# %%
plt.plot(x,y,'orange')

# %%
plt.plot(x,y,'orange')
plt.show()

# %%
plt.plot(x,y,'green')
plt.xlabel('variables')
plt.ylabel('sqrt')
plt.title('variable sqrt')
plt.show()

# %%
plt.plot(x, y, 'blue')
plt.xlabel("Variable")
plt.ylabel("Square of Variable")
plt.title('Var vs Sq. of var')
plt.show()

# %%
plt.plot(x, y, 'b--')
plt.xlabel("Variable")
plt.ylabel("Square of Variable")
plt.title('Var vs Sq. of var')
plt.show()

# %%
plt.plot(x, y, 'r',marker='o')
plt.xlabel("Variable")
plt.ylabel("Square of Variable")
plt.title('Var vs Sq. of var')
plt.show()

# %%
plt.plot(x, y, '#FF3487', marker='o')
plt.xlabel("Variable")
plt.ylabel("Square of Variable")
plt.title('Var vs Sq. of var')
plt.show()

# %%
plt.plot(x, y, 'red', marker='o')
plt.xlabel("Variable")
plt.ylabel("Square of Variable")
plt.title('Var vs Sq. of var')
plt.show()

# %%
plt.plot(x, y, 'pink', marker='o')
plt.xlabel("Variable")
plt.ylabel("Square of Variable")
plt.title('Var vs Sq. of var')
plt.show()

# %%
plt.plot(x, y, '#FF3487', marker='o' , linewidth=10)
plt.xlabel("Variable")
plt.ylabel("Square of Variable")
plt.title('Var vs Sq. of var')
plt.show()

# %%
plt.plot(x, y, '#FF3487', marker='o' , linewidth=20)
plt.xlabel("Variable")
plt.ylabel("Square of Variable")
plt.title('Var vs Sq. of var')
plt.show()

# %%
plt.plot(x, y, '#FF3487', marker='o', linewidth=3, alpha=0.5)
plt.xlabel("Variable")
plt.ylabel("Square of Variable")
plt.title('Var vs Sq. of var')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y, 'r--')
plt.subplot(1,2,2)
plt.plot(y, x, 'b-')
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(x,y, 'r--')
plt.subplot(2,1,2)
plt.plot(y, x, 'b-')
plt.show()

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sns.distplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'], kde=False)

# %%
sns.distplot(tips['total_bill'], kde=False,bins=30)

# %%
sns.distplot(tips['total_bill'], kde=False,bins=50)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex')

# %%
sns.pairplot(tips, hue = 'smoker')

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())

# %%
sns.heatmap(tips.corr(), cmap='coolwarm')

# %%
sns.heatmap(tips.corr(), cmap='coolwarm', annot=True)
