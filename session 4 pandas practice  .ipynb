# %%
import pandas as pd

# %%
data=pd.read_csv('C:/Drivers/Salaries.csv')

# %%
data.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
data['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650         Not provided
# 148651         Not provided
# 148652         Not provided
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %%
data.loc[4]
# Out:
# Id                                                             5
# EmployeeName                                     PATRICK GARDNER
# JobTitle            DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# BasePay                                                   134402
# OvertimePay                                                 9737
# OtherPay                                                  182235
# Benefits                                                     NaN
# TotalPay                                                  326373
# TotalPayBenefits                                          326373
# Year                                                        2011
# Notes                                                        NaN
# Agency                                             San Francisco
# Status                                                       NaN
# Name: 4, dtype: object

# %%
data.iloc[4]
# Out:
# Id                                                             5
# EmployeeName                                     PATRICK GARDNER
# JobTitle            DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# BasePay                                                   134402
# OvertimePay                                                 9737
# OtherPay                                                  182235
# Benefits                                                     NaN
# TotalPay                                                  326373
# TotalPayBenefits                                          326373
# Year                                                        2011
# Notes                                                        NaN
# Agency                                             San Francisco
# Status                                                       NaN
# Name: 4, dtype: object

# %%
data.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448841    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
data.set_index('Id',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-e0aea2e336a8> in <module>
# ----> 1 data.set_index('Id',inplace=True)
#
# C:\ProgramData2\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Id'] are in the columns"

# %%
data
# Out:
#              EmployeeName                                        JobTitle  \
# Id
# 1          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 3          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 5         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148650      Roy I Tillery                                       Custodian
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653       Not provided                                    Not provided
# 148654          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# Id
# ...

# %%
data.loc[2]
# Out:
# EmployeeName                           GARY JIMENEZ
# JobTitle            CAPTAIN III (POLICE DEPARTMENT)
# BasePay                                      155966
# OvertimePay                                  245132
# OtherPay                                     137811
# Benefits                                        NaN
# TotalPay                                     538909
# TotalPayBenefits                             538909
# Year                                           2011
# Notes                                           NaN
# Agency                                San Francisco
# Status                                          NaN
# Name: 2, dtype: object

# %%
data.iloc[1]
# Out:
# EmployeeName                           GARY JIMENEZ
# JobTitle            CAPTAIN III (POLICE DEPARTMENT)
# BasePay                                      155966
# OvertimePay                                  245132
# OtherPay                                     137811
# Benefits                                        NaN
# TotalPay                                     538909
# TotalPayBenefits                             538909
# Year                                           2011
# Notes                                           NaN
# Agency                                San Francisco
# Status                                          NaN
# Name: 2, dtype: object

# %%
data.loc[1]
# Out:
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                     167411
# OvertimePay                                                      0
# OtherPay                                                    400184
# Benefits                                                       NaN
# TotalPay                                                    567595
# TotalPayBenefits                                            567595
# Year                                                          2011
# Notes                                                          NaN
# Agency                                               San Francisco
# Status                                                         NaN
# Name: 1, dtype: object

# %%
data.iloc[0]
# Out:
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                     167411
# OvertimePay                                                      0
# OtherPay                                                    400184
# Benefits                                                       NaN
# TotalPay                                                    567595
# TotalPayBenefits                                            567595
# Year                                                          2011
# Notes                                                          NaN
# Agency                                               San Francisco
# Status                                                         NaN
# Name: 1, dtype: object

# %%
data['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %%
data['JobTitle'].nunique()
# Out:
# 2159

# %%
data['JobTitle'].value_counts()
# Out:
# Transit Operator                  7036
# Special Nurse                     4389
# Registered Nurse                  3736
# Public Svc Aide-Public Works      2518
# Police Officer 3                  2421
#                                   ...
# FORENSIC TOXICOLOGIST                1
# CARPENTER SUPERVISOR II              1
# Asst Dir Clinical Svcs 2             1
# Pr DistAtty Invstgtor,SpecUnit       1
# SHELTER OFFICE SUPERVISOR            1
# Name: JobTitle, Length: 2159, dtype: int64

# %%
data['JobTitle'].value_counts().head()
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
#Lambda function

# %%
data['OvertimePay'].apply(lambda x: x*2)
# Out:
# Id
# 1              0.00
# 2         490263.76
# 3         212176.36
# 4         112241.42
# 5          19474.00
#             ...
# 148650         0.00
# 148651          NaN
# 148652          NaN
# 148653          NaN
# 148654         0.00
# Name: OvertimePay, Length: 148654, dtype: float64

# %%
print(182234.59*182234.59)
# Out:
# 33209445792.468098

# %%
print(9737.00*2)
# Out:
# 19474.0

# %%
def into2(overtime):
     return overtime*3

# %%
data['OvertimePay'].apply(into2)
# Out:
# Id
# 1              0.00
# 2         735395.64
# 3         318264.54
# 4         168362.13
# 5          29211.00
#             ...
# 148650         0.00
# 148651          NaN
# 148652          NaN
# 148653          NaN
# 148654         0.00
# Name: OvertimePay, Length: 148654, dtype: float64

# %%
print(9737.00*3)
# Out:
# 29211.0

# %%
data.sort_values('BasePay', ascending=False)
# Out:
#                 EmployeeName                      JobTitle    BasePay  \
# Id
# 72926         Gregory P Suhr               Chief of Police  319275.01
# 110533            Amy P Hart             Asst Med Examiner  318835.49
# 72930          Robert L Shaw  Dep Dir for Investments, Ret  315572.01
# 72927   Joanne M Hayes-White        Chief, Fire Department  313686.01
# 72932      Harlan L Kelly-Jr   Executive Contract Employee  313312.52
# ...                      ...                           ...        ...
# 110531         David P Kucia              Police Officer 3        NaN
# 148647          Not provided                  Not provided        NaN
# 148651          Not provided                  Not provided        NaN
# 148652          Not provided                  Not provided        NaN
# 148653          Not provided                  Not provided        NaN
#
#         OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# Id
# ...

# %%
data.isnull()
# Out:
#         EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  Benefits  \
# Id
# 1              False     False    False        False     False      True
# 2              False     False    False        False     False      True
# 3              False     False    False        False     False      True
# 4              False     False    False        False     False      True
# 5              False     False    False        False     False      True
# ...              ...       ...      ...          ...       ...       ...
# 148650         False     False    False        False     False     False
# 148651         False     False     True         True      True      True
# 148652         False     False     True         True      True      True
# 148653         False     False     True         True      True      True
# 148654         False     False    False        False     False     False
#
#         TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# Id
# ...

# %%
data.drop('Notes',axis=1)
# Out:
#              EmployeeName                                        JobTitle  \
# Id
# 1          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 3          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 5         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148650      Roy I Tillery                                       Custodian
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653       Not provided                                    Not provided
# 148654          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# Id
# ...

# %%
data.dropna()
# Out:
# Empty DataFrame
# Columns: [EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency, Status]
# Index: []

# %%
data.dropna(thresh=8)
# Out:
#              EmployeeName                                        JobTitle  \
# Id
# 1          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 3          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 5         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148646   Carolyn A Wilson                       Human Services Technician
# 148648     Joann Anderson                     Communications Dispatcher 2
# 148649        Leon Walker                                       Custodian
# 148650      Roy I Tillery                                       Custodian
# 148654          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# Id
# ...

# %%
data.dropna(axis=1)
# Out:
#              EmployeeName                                        JobTitle  \
# Id
# 1          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 3          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 5         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148650      Roy I Tillery                                       Custodian
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653       Not provided                                    Not provided
# 148654          Joe Lopez                      Counselor, Log Cabin Ranch
#
#          TotalPay  TotalPayBenefits  Year         Agency
# Id
# ...

# %%
data.dropna(thresh=120000,axis=1)
# Out:
#              EmployeeName                                        JobTitle  \
# Id
# 1          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 3          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 5         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148650      Roy I Tillery                                       Custodian
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653       Not provided                                    Not provided
# 148654          Joe Lopez                      Counselor, Log Cabin Ranch
#
# ...

# %%
data.dropna(axis=1)
# Out:
#              EmployeeName                                        JobTitle  \
# Id
# 1          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 3          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 5         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148650      Roy I Tillery                                       Custodian
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653       Not provided                                    Not provided
# 148654          Joe Lopez                      Counselor, Log Cabin Ranch
#
#          TotalPay  TotalPayBenefits  Year         Agency
# Id
# ...

# %%
data
# Out:
#              EmployeeName                                        JobTitle  \
# Id
# 1          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 3          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 5         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148650      Roy I Tillery                                       Custodian
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653       Not provided                                    Not provided
# 148654          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# Id
# ...

# %%
data.fillna('ABCD')
# Out:
#              EmployeeName                                        JobTitle  \
# Id
# 1          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 3          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 5         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148650      Roy I Tillery                                       Custodian
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653       Not provided                                    Not provided
# 148654          Joe Lopez                      Counselor, Log Cabin Ranch
#
# ...

# %%
data['Benefits']
# Out:
# Id
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
#          ...
# 148650    0.0
# 148651    NaN
# 148652    NaN
# 148653    NaN
# 148654    0.0
# Name: Benefits, Length: 148654, dtype: float64

# %%
data["Benefits"].fillna(value=data['Benefits'].mean())
# Out:
# Id
# 1         25007.893151
# 2         25007.893151
# 3         25007.893151
# 4         25007.893151
# 5         25007.893151
#               ...
# 148650        0.000000
# 148651    25007.893151
# 148652    25007.893151
# 148653    25007.893151
# 148654        0.000000
# Name: Benefits, Length: 148654, dtype: float64

# %%
data.dropna(thresh=10, axis=1)
# Out:
#              EmployeeName                                        JobTitle  \
# Id
# 1          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 3          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 5         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148650      Roy I Tillery                                       Custodian
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653       Not provided                                    Not provided
# 148654          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# Id
# ...
